# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/togeka/Desktop/career/quant_resources/ISLP_examples/islp_data/Auto.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are quali-
# tative?
#
# quantitative: cylinders, displacement, horsepower, weight, acceleration
#
# qualitative: year, origin, name

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can an-
# swer this using the min() and max() methods in numpy.
#
# (c) What is the mean and standard deviation of each quantitative .max()
# predictor?

# %%
quant = df[['mpg','cylinders','displacement','horsepower','weight','acceleration']]
quant.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %% [markdown]
# Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
subset = quant[(quant.index < 10) | (quant.index > 85)]
subset.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  321.000000  321.000000    321.000000   321.000000    321.000000
# mean    24.444860    5.370717    187.174455  2933.183801     15.709034
# std      7.899928    1.653486     99.864568   809.638650      2.706441
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    145.000000  2795.000000     15.500000
# 75%     30.700000    6.000000    250.000000  3504.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000

# %%
g = sns.PairGrid(quant)
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.fig.set_size_inches(12, 12)

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.
#
# weight, displacement and horsepower seem like a good guess. We see there is a non-linear inverse relationship
